# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
titanic_df= pd.read_csv('titanic.csv')
titanic_df

fare=titanic_df['Fare']
age=titanic_df['Age']
colors = {'male':'red', 'female':'black'}
plt.scatter(titanic_df.Fare,titanic_df.Age,c=titanic_df['Sex'].apply(lambda x: colors[x]))

plt.xlabel('Fare')
plt.ylabel('Age')
plt.title('Fare paid and the Age')
plt.show()

# %%
titanic_df['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
titanic_df['Embarked'] == "C" 
titanic_df["Embarked"].head(5)
# Out:
# 0    S
# 1    C
# 2    S
# 3    S
# 4    S
# Name: Embarked, dtype: object

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
titanic_df= pd.read_csv('titanic.csv')
titanic_df

a=titanic_df.loc[:,'Fare']
a
print(a.sum())
print(a.min())
print(a.max())
print(a.median())
print(a.std())
print(a.var())
print(a.prod())

# %%
titanic_df.info()
titanic_df.describe() ## Generate a summary of statistics for each numerical column of the data frame
titanic_df.nunique() #For the variables with less than 10 levels, we can list what these levels are using the method .unique():
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# ...

# %%
titanic_df['Embarked'].value_counts()

titanic_df['Pclass'].value_counts()
titanic_df.head(5)
titanic_df.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# ...

# %%
titanic_df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_df[titanic_df['Fare']==0].sort_values(by=['Ticket']) # sorting values of 0 by tickts
# Out:
#     PassengerId Survived Pclass                              Name   Sex   Age  \
# 806         807        0      1            Andrews, Mr. Thomas Jr  male  39.0
# 633         634        0      1     Parr, Mr. William Henry Marsh  male   NaN
# 815         816        0      1                  Fry, Mr. Richard  male   NaN
# 263         264        0      1             Harrison, Mr. William  male  40.0
# 822         823        0      1   Reuchlin, Jonkheer. John George  male  38.0
# 277         278        0      2       Parkes, Mr. Francis "Frank"  male   NaN
# 413         414        0      2    Cunningham, Mr. Alfred Fleming  male   NaN
# 466         467        0      2             Campbell, Mr. William  male   NaN
# 481         482        0      2  Frost, Mr. Anthony Wood "Archie"  male   NaN
# 732         733        0      2              Knight, Mr. Robert J  male   NaN
# 674         675        0      2        Watson, Mr. Ennis Hastings  male   NaN
# ...

# %%
import seaborn as sns
# Absolute frequency
sns.set_style("white")
g = sns.FacetGrid(data = titanic_df[titanic_df['Age'].notna()], col = 'Survived')
g.map(plt.hist, "Age");

# %%
# Relative frequency
dt0 = titanic_df['Age'][titanic_df['Survived']=='0']
dt1 = titanic_df['Age'][titanic_df['Survived']=='1']
bins = np.arange(0, titanic_df['Age'].max()+5, 5)
plt.hist([dt0,dt1], label=['Survived: No','Survived: Yes'])        
plt.legend(loc='upper right')
plt.title('Relative Frequency of Age');

# %%
#Drop the unwanted columns
n_titanic_data=titanic_df.drop(['Cabin','Ticket','Name','Fare','PassengerId'],axis=1)
n_titanic_data
# Out:
#     Survived Pclass     Sex   Age  SibSp  Parch Embarked
# 0          0      3    male  22.0      1      0        S
# 1          1      1  female  38.0      1      0        C
# 2          1      3  female  26.0      0      0        S
# 3          1      1  female  35.0      1      0        S
# 4          0      3    male  35.0      0      0        S
# ..       ...    ...     ...   ...    ...    ...      ...
# 886        0      2    male  27.0      0      0        S
# 887        1      1  female  19.0      0      0        S
# 888        0      3  female   NaN      1      2        S
# 889        1      1    male  26.0      0      0        C
# 890        0      3    male  32.0      0      0        Q
#
# [891 rows x 7 columns]

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data=titanic_df, x='Age', kde=True, hue='Sex')
plt.title('Age Distribution by Gender')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=titanic_df, x='Embarked', hue='Survived')
plt.title('Survival Count based on Embarkation Port')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=titanic_df, x='Pclass', y='Fare', hue='Survived')
plt.ylim(0, 300)  # Limiting y-axis to 300 for better visualization
plt.title('Fare distribution by Passenger Class and Survival')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=titanic_df, x='Pclass', y='Survived', hue='Sex')
plt.title('Survival Rate by Passenger Class and Gender')
plt.show()

# %%
#It  helps us to make an assumption on fares and the ticket class.
class_fare = titanic_df.pivot_table(index='Pclass', values='Fare')
class_fare.plot(kind='bar',color='red')
plt.xlabel('Pclass')
plt.ylabel('Avg. Fare')
plt.xticks(rotation=0)
plt.show()

# %%
titanic_df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
# Group the dataset by Pclass and Survived and then unstack them
group = titanic_df.groupby(['Pclass', 'Survived'])
pclass_survived = group.size().unstack()
 
# Heatmap - Color encoded 2D representation of data.
sns.heatmap(pclass_survived, annot = True, fmt ="d")
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
# Countplot
sns.catplot(x ='Embarked', hue ='Survived', 
kind ='count', col ='Pclass', data = titanic_df)

# %%
df_num = titanic_df[['Age','SibSp','Parch','Fare']]
df_cat = titanic_df[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]
for i in df_num.columns:
plt.hist(df_num[i])
plt.title(i)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
import pandas as pd
titanic= pd.read_csv('titanic.csv')
titanic

count=titanic['Sex'].value_counts()
colors = ['red', 'green']
plt.pie(count.values.tolist(), labels=count.index.values.tolist(), colors=colors,startangle=120,autopct='%.1f%%')
plt.title('Male/Female proportion')
plt.show()

# %%
dataf = pd.DataFrame([
    ['John Smith','123 Main St',34],
    ['Jane Doe', '456 Maple Ave',28],
    ['Joe Schmo', '789 Broadway',51]
    ],
    columns=['name','address','age'])
dataf
# Out:
#          name        address  age
# 0  John Smith    123 Main St   34
# 1    Jane Doe  456 Maple Ave   28
# 2   Joe Schmo   789 Broadway   51

# %%
# When we have to work on Tabular data, we prefer the pandas module.
# The powerful tools of pandas are DataFrame and Series.
